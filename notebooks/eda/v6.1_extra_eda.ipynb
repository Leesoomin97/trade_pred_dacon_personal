# %%
# ============================================================
# EDA Core Script v2 (for trade competition)
# Purpose: HS4 corr, lead-lag corr, DTW, ratio corr
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from scipy.signal import correlate
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw

# %%
# ------------------------------------------------------------
# Load processed monthly file
# ------------------------------------------------------------
df = pd.read_csv("../../data/processed/train_monthly_v3_eda.csv")

# pivot by item × month index
pivot = df.pivot(index="item_id", columns="t", values="total_value").fillna(0)
pivot_norm = pivot.apply(lambda x: (x - x.min()) / (x.max() - x.min() + 1e-9), axis=1)

item_ids = pivot.index.tolist()
hs4_map = df.groupby("item_id")["hs4"].first().to_dict()

print("Loaded pivot:", pivot.shape)

# ============================================================
# 1. HS4 Internal Correlation Matrix
# ============================================================
hs4_corr_results = {}

for hs4, sub in df.groupby("hs4"):
    items = sub["item_id"].unique()
    if len(items) < 2:
        continue
    
    p = pivot_norm.loc[items]

    corr_mat = p.T.corr()
    hs4_corr_results[hs4] = corr_mat

    plt.figure(figsize=(8,6))
    sns.heatmap(corr_mat, annot=False, cmap="coolwarm", vmin=-1, vmax=1)
    plt.title(f"HS4={hs4} Internal Correlation ({len(items)} items)")
    plt.tight_layout()
    plt.savefig(f"eda_hs4_corr_{hs4}.png")
    plt.close()

print("HS4 corr 완료")


# ============================================================
# 2. Lead-Lag Cross Correlation (A leads B)
# ============================================================
def best_leadlag(x, y, max_lag=6):
    best_corr = 0
    best_lag = None

    if np.std(x) == 0 or np.std(y) == 0:
        return None, 0

    for lag in range(1, max_lag+1):
        if len(x) <= lag: 
            continue

        # A(t) vs B(t+lag)
        c = np.corrcoef(x[:-lag], y[lag:])[0,1]
        if abs(c) > abs(best_corr):
            best_corr = c
            best_lag = lag

    return best_lag, best_corr


results = []

for A in tqdm(item_ids):
    x = pivot_norm.loc[A].values
    for B in item_ids:
        if A == B:
            continue
        y = pivot_norm.loc[B].values

        lag, corr = best_leadlag(x, y)
        if lag is not None:
            results.append([A, B, lag, corr])

lag_df = pd.DataFrame(results, columns=["A", "B", "best_lag", "best_corr"])
lag_df.to_csv("eda_lag_leadlag.csv", index=False)
print("Lead-Lag corr 완료")


# ============================================================
# 3. DTW Distance Matrix
# ============================================================
# ============================================================
# 3. DTW Distance Matrix (robust version)
# ============================================================

dtw_list = []

for A in tqdm(item_ids):
    x = pivot_norm.loc[A].values.astype(float).reshape(-1)
    
    # 길이 부족/변동성 없음 → skip
    if len(x) < 3 or np.std(x) < 1e-8:
        continue
    
    for B in item_ids:
        if A == B:
            continue
        
        y = pivot_norm.loc[B].values.astype(float).reshape(-1)
        
        if len(y) < 3 or np.std(y) < 1e-8:
            continue

        # DTW 계산
        try:
            dist, _ = fastdtw(x, y, dist=euclidean)
        except Exception as e:
            print(f"DTW fail: {A}, {B}, reason={e}")
            continue

        dtw_list.append([A, B, dist])

dtw_df = pd.DataFrame(dtw_list, columns=["A", "B", "dtw_dist"])
dtw_df.to_csv("eda_dtw_matrix.csv", index=False)
print("DTW 완료 (안 터짐)")


# ============================================================
# 4. Ratio Corr (weight/value)
# ============================================================
pivot_ratio = df.pivot(index="item_id", columns="t", values="wv_ratio").fillna(0)
ratio_corr = pivot_ratio.T.corr()
ratio_corr.to_csv("eda_ratio_corr.csv")

plt.figure(figsize=(9,7))
sns.heatmap(ratio_corr, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Ratio (weight/value) Corr")
plt.tight_layout()
plt.savefig("eda_ratio_corr.png")
plt.close()

print("Ratio corr 완료")

print("\n🎉 EDA Core v2 완성! 의미 없는 그래프 없이, 실제로 FE에 필요한 기능만 넣음.")
# Out:
# Loaded pivot: (100, 43)
# HS4 corr 완료
#   0%|                                                                                                                    | 0/100 [00:00<?, ?it/s]/data/ephemeral/home/py310/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /data/ephemeral/home/py310/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 31.24it/s]
# Lead-Lag corr 완료
#  23%|████████████████████████▍                                                                                 | 23/100 [00:00<00:00, 109.17it/s]
# DTW fail: AANGBULD, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: AANGBULD, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: AHMDUILJ, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: ANWUJOKX, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: APQGTRMF, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: ATLDMDBO, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: AXULOHBQ, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: BEZYMBBT, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: BJALXPFS, HCDTGMST, reason=Input vector should be 1-D.
# ...
# DTW fail: ZGJXVMNI, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, ZKENOUDA, reason=Input vector should be 1-D.
# DTW fail: ZGJXVMNI, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: ZKENOUDA, ZXERAXWP, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, AANGBULD, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, AHMDUILJ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ANWUJOKX, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, APQGTRMF, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ATLDMDBO, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, AXULOHBQ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, BEZYMBBT, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, BJALXPFS, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, BLANHGYY, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, BSRMSVTC, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, BTMOEMEP, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, BUZIIBYG, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, CCLHWFWF, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, DBWLZWNK, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, DDEXPPXU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, DEWLVASR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, DJBLNPNC, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, DNMPSKTB, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, DUCMGGNW, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ELQGMQWE, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, EVBVXETX, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FCYBOAXC, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FDXPMYGF, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FITUEHWN, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FQCLOEXA, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FRHNWLNI, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FTSVTTSR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, FWUCPMMW, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, GIKPEWTY, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, GKQIJYDH, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, GMBFCMIU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, GYHKIVQT, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, HCDTGMST, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, HXYSSRXE, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, IGDVVKUD, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, JBVHSUWY, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, JERHKLYW, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, JPBRUTWP, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, JSLXRQOK, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, KAGJCHMR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, KEUWZRKO, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, KFQSHBNH, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, KJNSOAHR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, LLHREMKS, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, LPHPPJUG, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, LRVGFDFM, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, LSOIUSXD, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, LTOYKIML, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, LUENUFGA, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, MBSBZBXA, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, MIRCVAMV, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, NAQIHUKZ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, NZKBIBNU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, OGAFEHLU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, OJIFIHMZ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, OKMBFVKS, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, OXKURKXR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, PLMZALFA, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, PYZMVUWD, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, QJQJSWFU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, QKXNTIIB, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, QRKRBYJL, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, QSDCUCLB, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, QVLMOEYE, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, RAWUKQMJ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, RCBZUSIM, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, RJCAXSGH, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, RJGPVEXX, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ROACSLMG, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, RUVXNNVA, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, SAAYMURU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, SAHWCZNH, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, SDWAYPIK, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, SNHYOVBM, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, STZDBITS, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, SUOYXCHP, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, TANNMIMB, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, TGOELCAG, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, UGEQLMXM, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, UIFPPCLR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, UQYUIVVR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, UXSPKBJR, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, VBYCLTYZ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, VMAQSTJE, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, VUAFAIYJ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, VWMBASNE, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, WBLJNPZQ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, WHPUAOID, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, WPQXWHYO, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, WQMVCOEM, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, XIFHSOWQ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, XIIEJNEE, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, XIPPENFQ, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, XMKRPGLB, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, XUOIQPFL, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, YSYHGLQK, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ZCELVYQU, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ZGJXVMNI, reason=Input vector should be 1-D.
# DTW fail: ZXERAXWP, ZKENOUDA, reason=Input vector should be 1-D.
# DTW 완료 (안 터짐)
# Ratio corr 완료
#
# 🎉 EDA Core v2 완성! 의미 없는 그래프 없이, 실제로 FE에 필요한 기능만 넣음.
